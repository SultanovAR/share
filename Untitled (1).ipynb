# %% [markdown]
# ## План выступления
#
# - Способы оценок важности признаков для модели в конкретный момент времени
#     - Описание способа Permutation Importance (нас интересуют относительные величины)
#     - Упоминание других (shap, random forest), с указанием, что при тестировании они показали себя идентичным образом
#     - Минусы способа(важность размазывается среди коррелированных признаков, пример с MNIST)
# - Способы оценок важности признаков для модели через время
#     Записываем важность признаков в таблицу, в дальнейших пунктах будем использовать среднее значение значимости среди всех выборок(моментов времени)
# - Способы агрегации важности признаков среди моделей
#     Для аггрегации важности признаков от разных моделей будем использовать взвшенной среднее
#     - коэф по степени значимости
#         0 - для низкой
#         0.5 - для средней
#         1 - для высокой
#     - коэф по светофору (по самому последнему OOT)
#         0 - для красных
#         0.5 - для желтых
#         1 - для зеленых
#     - коэф от валидора
#         1 - стандарт
#         3 - модель важна

# %%
э
